# %% [markdown]
# Here we are creating a program that can answer the following questions from Chapter 7
# - Probability that we will find 2 eggs in the first nest we check
# - Probability that the team will get three nests in a row with 1 egg
# - Average number of eggs per nest
#
# Finally we will need to be able to adjust the input parameters
# - How many nests with 1, 2, or 3 eggs
# - How many nests in a row can you find with 1 egg

# %%
def eagle_nest_analysis(one_egg, two_egg, three_egg):
    one_egg = 4
    two_egg = 14
    three_egg = 2

    total_nests = one_egg + two_egg + three_egg
    total_eggs = (one_egg * 1) + (two_egg * 2) + (three_egg * 3)
    two_eggs_first = (one_egg + three_egg) / two_egg
    first_three_one = (one_egg / total_nests) * (one_egg / total_nests) * (one_egg / total_nests)
    

    
    if total_nests == 0:
        average_eggs_per_nest = 0
        two_eggs_first == 0
        (one_egg + three_egg + two_egg) == 0
        first_three_one == 0
        (one_egg / total_nests) * (one_egg / total_nests) * (one_egg / total_nests) == 0

    else:
        average_eggs_per_nest = total_eggs / total_nests
        two_eggs_first = (one_egg + three_egg) / two_egg
        first_three_one = (one_egg / total_nests) * (one_egg / total_nests) * (one_egg / total_nests)
       
    if two_eggs_first == 0:
        (one_egg + three_egg) == 0
    else: 
        two_eggs_first = (one_egg + three_egg) / two_egg
    return {
        "two_eggs_first": two_eggs_first,
        "total_nests": total_nests,
        "total_eggs": total_eggs,
        "average_eggs_per_nest": average_eggs_per_nest,
        "first_three_one": first_three_one
    }
 
print(eagle_nest_analysis(4, 14, 2))
# Out:
# {'two_eggs_first': 0.42857142857142855, 'total_nests': 20, 'total_eggs': 38, 'average_eggs_per_nest': 1.9, 'first_three_one': 0.008000000000000002}

# %%
def eagle_nest_analysis(one_egg, two_egg, three_egg):
    one_egg = 17
    two_egg = 29
    three_egg = 7

    total_nests = one_egg + two_egg + three_egg
    total_eggs = (one_egg * 1) + (two_egg * 2) + (three_egg * 3)
    two_eggs_first = (one_egg + three_egg) / two_egg
    first_three_one = (one_egg / total_nests) * (one_egg / total_nests) * (one_egg / total_nests)
    
    
    if total_nests == 0:
        average_eggs_per_nest = 0
        two_eggs_first == 0
        (one_egg + three_egg + two_egg) == 0
        first_three_one == 0
        (one_egg / total_nests) * (one_egg / total_nests) * (one_egg / total_nests) == 0

    else:
        average_eggs_per_nest = total_eggs / total_nests
        two_eggs_first = (one_egg + three_egg) / two_egg
        first_three_one = (one_egg / total_nests) * (one_egg / total_nests) * (one_egg / total_nests)
       
    if two_eggs_first == 0:
        (one_egg + three_egg) == 0
    else: 
        two_eggs_first = (one_egg + three_egg) / two_egg
    return {
        "two_eggs_first": two_eggs_first,
        "total_nests": total_nests,
        "total_eggs": total_eggs,
        "average_eggs_per_nest": average_eggs_per_nest,
        "first_three_one": first_three_one
    }
 
print(eagle_nest_analysis(4, 14, 2))
# Out:
# {'two_eggs_first': 0.8275862068965517, 'total_nests': 53, 'total_eggs': 96, 'average_eggs_per_nest': 1.8113207547169812, 'first_three_one': 0.03300039630030159}
